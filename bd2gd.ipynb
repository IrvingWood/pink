# %%
import pandas as pd

# %%
data = pd.read_csv("a.csv")
data.head()
# Out:
#                             adress  bd2gddistance
# 0  上海市静安区堡尼大厦西北门旁(延长路地铁站3号口步行140米)      18.621868
# 1   上海市长宁区天山公园东门南250米(延安西路地铁站2号口旁)      13.915124
# 2             上海市黄浦区日月光618号9号线1号B2     626.566696
# 3                 上海市黄浦区金日世家北门东60米       1.322763
# 4            上海市浦东新区国展路1481号航融盛通大厦      78.971726

# %%
data = data[~data['adress'].duplicated(keep="first")]

# %%
distance = data["bd2gddistance"]

# %%
import numpy as np
np.set_printoptions(suppress=True)
data100 = data[distance.values>100]

# %%
data100["备注"]="1"
# Out:
# C:\Users\13202\AppData\Local\Temp\ipykernel_9788\774238983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data100["备注"]="1"

# %%
data100["备注"].loc[2]="百度无地址"
# Out:
# C:\Users\13202\AppData\Local\Temp\ipykernel_9788\3550696517.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data100["备注"].loc[2]="百度无地址"
# ...

# %%
data100
# Out:
#                                    adress  bd2gddistance     备注
# 2                    上海市黄浦区日月光618号9号线1号B2     626.566696  百度无地址
# 7    上海市静安区北京西路1748号2幢底商(静安寺地铁站1号口步行330米)     334.095333      1
# 15          上海市黄浦区马当路388号SOHO复兴广场E栋一层107号     110.658331      1
# 45               上海市普陀区中江路388弄国盛中心1号101A室     341.416832      1
# 56             上海市长宁区凯旋路1398号IM长宁国际LG层41号     196.521866      1
# 67             上海市浦东新区博成路568号中国黄金大厦B座一层大堂     171.913136      1
# 69           上海市虹口区河南北路99号上海兴旺国际服饰城一层M78室     112.973383      1
# 77       上海市长宁区长宁路88号King88广场负一层B1-09-01室     108.664605      1
# 82             上海市浦东新区银城路9号浦江双辉广场负一层101商铺     103.338465      1
# 92                      上海市宝山区馨佳园九街坊东北2门旁     143.765114      1
# 108           上海市浦东新区浦东南路1138号上海湾广场一层116室     114.003109      1
# 114      上海市徐汇区漕溪北路1200号地铁1号线上海体育馆站7号口负一层     243.559660      1
# 120              上海市浦东新区哈雷路与李时珍路交叉口东南140米     841.553639      1
# 125                 上海市宝山区菊太路与宝富路交叉口西160米     325.664497      1
# ...

# %%
bins = [0, 50, 100, 500]
labels = pd.cut(distance, bins)
interval_counts = labels.value_counts(sort=False)

# %%
interval_counts
# Out:
# bd2gddistance
# (0, 50]       131
# (50, 100]      31
# (100, 500]     15
# Name: count, dtype: int64

# %%
data[data["bd2gddistance"]>100].shape
# Out:
# (18, 2)

# %%
data100["备注"].loc[182]="平台地址不一"
# Out:
# C:\Users\13202\AppData\Local\Temp\ipykernel_9788\1671917928.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data100["备注"].loc[182]="平台地址不一"
# ...

# %%
data100["备注"].loc[160]="公平路36号负一层9-1室"
# Out:
# C:\Users\13202\AppData\Local\Temp\ipykernel_9788\2560103471.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data100["备注"].loc[160]="公平路36号负一层9-1室"
# ...

# %%
data100["备注"].loc[120]="百度无地址"
# Out:
# C:\Users\13202\AppData\Local\Temp\ipykernel_9788\793578845.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data100["备注"].loc[120]="百度无地址"
# ...

# %%
data100["备注"].loc[129]="上海市长宁区新华路664号25号万宝国际商务中心一层大堂"
# Out:
# C:\Users\13202\AppData\Local\Temp\ipykernel_9788\2281209640.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data100["备注"].loc[129]="上海市长宁区新华路664号25号万宝国际商务中心一层大堂"
# ...

# %%
data100.index.to_numpy()
# Out:
# array([  2,   7,  15,  45,  56,  67,  69,  77,  82,  92, 108, 114, 120,
#        125, 129, 132, 160, 182])

# %%
ndata = pd.read_csv("b.csv")
ndata100  = ndata[ndata["distance"]>100]

# %%
ndata100.index
# Out:
# Index([  2,  15,  16,  19,  22,  35,  36,  39,  40,  45,  47,  48,  49,  50,
#         54,  56,  65,  66,  67,  72,  82,  84,  91,  92,  93, 102, 103, 108,
#        111, 120, 125, 127, 129, 134, 136, 139, 142, 144, 145, 150, 157, 159,
#        166, 173, 176, 186, 187],
#       dtype='int64')

# %%
import numpy as np

# %%
np.intersect1d(data100.index.to_numpy(), ndata100.index.to_numpy())
# Out:
# array([  2,  15,  45,  56,  67,  82,  92, 108, 120, 125, 129])

# %%
len(np.intersect1d(data100.index.to_numpy(), ndata100.index.to_numpy()))
# Out:
# 11

# %%
optimize_index = np.setdiff1d(data100.index.to_numpy(), np.intersect1d(data100.index.to_numpy(), ndata100.index.to_numpy()))

# %%
data100[data100.index.isin(optimize_index)]
# Out:
#                                    adress  bd2gddistance             备注
# 7    上海市静安区北京西路1748号2幢底商(静安寺地铁站1号口步行330米)     334.095333              1
# 69           上海市虹口区河南北路99号上海兴旺国际服饰城一层M78室     112.973383              1
# 77       上海市长宁区长宁路88号King88广场负一层B1-09-01室     108.664605              1
# 114      上海市徐汇区漕溪北路1200号地铁1号线上海体育馆站7号口负一层     243.559660              1
# 132      上海市黄浦区徐家汇路618号日月光中心负二层B2-RJ-28B室     120.334684              1
# 160                   上海市虹口区公平路36号负一层9-1室     173.048967  公平路36号负一层9-1室
# 182   上海市浦东新区张杨路2389弄1-2号置汇旭辉广场购物中心负一层10室     145.394049         平台地址不一

# %%
ndata.loc[optimize_index]
# Out:
#                                        adress   distance
# 7    上海市静安区北京西路1748号2幢底商(静安寺地铁站1号口步行330米)瑞幸咖啡   3.868101
# 69           上海市虹口区河南北路99号上海兴旺国际服饰城一层M78室瑞幸咖啡  50.320472
# 77       上海市长宁区长宁路88号King88广场负一层B1-09-01室瑞幸咖啡  21.189470
# 114      上海市徐汇区漕溪北路1200号地铁1号线上海体育馆站7号口负一层瑞幸咖啡   1.648486
# 132      上海市黄浦区徐家汇路618号日月光中心负二层B2-RJ-28B室瑞幸咖啡  10.824453
# 160                   上海市虹口区公平路36号负一层9-1室瑞幸咖啡  11.952074
# 182   上海市浦东新区张杨路2389弄1-2号置汇旭辉广场购物中心负一层10室瑞幸咖啡  13.626269

# %%
data100
# Out:
#                                    adress  bd2gddistance  \
# 2                    上海市黄浦区日月光618号9号线1号B2     626.566696
# 7    上海市静安区北京西路1748号2幢底商(静安寺地铁站1号口步行330米)     334.095333
# 15          上海市黄浦区马当路388号SOHO复兴广场E栋一层107号     110.658331
# 45               上海市普陀区中江路388弄国盛中心1号101A室     341.416832
# 56             上海市长宁区凯旋路1398号IM长宁国际LG层41号     196.521866
# 67             上海市浦东新区博成路568号中国黄金大厦B座一层大堂     171.913136
# 69           上海市虹口区河南北路99号上海兴旺国际服饰城一层M78室     112.973383
# 77       上海市长宁区长宁路88号King88广场负一层B1-09-01室     108.664605
# 82             上海市浦东新区银城路9号浦江双辉广场负一层101商铺     103.338465
# 92                      上海市宝山区馨佳园九街坊东北2门旁     143.765114
# 108           上海市浦东新区浦东南路1138号上海湾广场一层116室     114.003109
# 114      上海市徐汇区漕溪北路1200号地铁1号线上海体育馆站7号口负一层     243.559660
# 120              上海市浦东新区哈雷路与李时珍路交叉口东南140米     841.553639
# 125                 上海市宝山区菊太路与宝富路交叉口西160米     325.664497
# 129                 上海市长宁区轨道交通三号线延安西路站1号口     622.537871
# ...

# %%
data100[data100.index.isin(ndata100.index)].sort_values(by="bd2gddistance")
# Out:

# Out:
# C:\Users\13202\AppData\Local\Temp\ipykernel_9788\1787283930.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data100["备注"].loc[45]="上海市普陀区中江路118弄28号海亮大厦A座底商(高德坐标偏差)"
# ...

# %%
data100["备注"].loc[82]="百度编码误差"
# Out:
# C:\Users\13202\AppData\Local\Temp\ipykernel_9788\2929333491.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data100["备注"].loc[82]="百度编码误差"
# ...

# %%
data100["备注"].loc[108]="高德坐标偏差"
# Out:
# C:\Users\13202\AppData\Local\Temp\ipykernel_9788\1325783153.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data100["备注"].loc[108]="高德坐标偏差"
# ...

# %%
data100["备注"].loc[15]="高德坐标偏差"
# Out:
# C:\Users\13202\AppData\Local\Temp\ipykernel_9788\2584119427.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data100["备注"].loc[15]="高德坐标偏差"
# ...

# %%
data100["备注"].loc[125]="上海市宝山区菊太路1217号一层2室"
# Out:
# C:\Users\13202\AppData\Local\Temp\ipykernel_9788\2273953806.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data100["备注"].loc[125]="上海市宝山区菊太路1217号一层2室"
# ...

# %%
data100["备注"].loc[56]="百度编码偏差"
# Out:
# C:\Users\13202\AppData\Local\Temp\ipykernel_9788\376103420.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data100["备注"].loc[56]="百度编码偏差"
# ...

# %%
data100["备注"].loc[67]="高德坐标偏差"
# Out:
# C:\Users\13202\AppData\Local\Temp\ipykernel_9788\201565097.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data100["备注"].loc[67]="高德坐标偏差"
# ...

# %%
data100["备注"].loc[92]="上海市菊盛路929号一层-2室"
# Out:
# C:\Users\13202\AppData\Local\Temp\ipykernel_9788\534062061.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data100["备注"].loc[92]="上海市菊盛路929号一层-2室"
# ...

# %%
data["adress"].unique
# Out:
# <bound method Series.unique of 0       上海市静安区堡尼大厦西北门旁(延长路地铁站3号口步行140米)
# 1        上海市长宁区天山公园东门南250米(延安西路地铁站2号口旁)
# 2                  上海市黄浦区日月光618号9号线1号B2
# 3                      上海市黄浦区金日世家北门东60米
# 4                 上海市浦东新区国展路1481号航融盛通大厦
#                      ...
# 195            上海市浦东新区福山路455号全华信息大厦一层大堂
# 196            上海市虹口区同丰路与北宝兴路辅路交叉口东140米
# 197    上海市长宁区天山路789号百盛优客城市广场东楼负一层E2001室
# 198          上海市浦东新区世纪大道1217号百联世纪购物中心F5
# 199           上海市普陀区中山北路2438号中瑞商务大厦一层大堂
# Name: adress, Length: 180, dtype: object>

# %%
data100["备注"].loc[160]="1"
# Out:
# C:\Users\13202\AppData\Local\Temp\ipykernel_9788\2316718157.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data100["备注"].loc[160]="1"
# ...

# %%
data100["备注"].loc[182]="1"
# Out:
# C:\Users\13202\AppData\Local\Temp\ipykernel_9788\4062111044.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data100["备注"].loc[182]="1"
# ...

# %%
data100["备注"].loc[129]="上海市长宁区新华路664号25号万宝国际商务中心一层大堂(高德地址错误)"
# Out:
# C:\Users\13202\AppData\Local\Temp\ipykernel_9788\3278971602.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data100["备注"].loc[129]="上海市长宁区新华路664号25号万宝国际商务中心一层大堂(高德地址错误)"
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of                                adress  bd2gddistance
# 0     上海市静安区堡尼大厦西北门旁(延长路地铁站3号口步行140米)      18.621868
# 1      上海市长宁区天山公园东门南250米(延安西路地铁站2号口旁)      13.915124
# 2                上海市黄浦区日月光618号9号线1号B2     626.566696
# 3                    上海市黄浦区金日世家北门东60米       1.322763
# 4               上海市浦东新区国展路1481号航融盛通大厦      78.971726
# ..                                ...            ...
# 195          上海市浦东新区福山路455号全华信息大厦一层大堂      18.390760
# 196          上海市虹口区同丰路与北宝兴路辅路交叉口东140米      22.715311
# 197  上海市长宁区天山路789号百盛优客城市广场东楼负一层E2001室      31.232050
# 198        上海市浦东新区世纪大道1217号百联世纪购物中心F5      46.008441
# 199         上海市普陀区中山北路2438号中瑞商务大厦一层大堂      20.667447
#
# [180 rows x 2 columns]>

# %%
data100
# Out:
#                                    adress  bd2gddistance  \
# 2                上海市黄浦区日月光618号9号线1号B2     626.566696
# 3                    上海市黄浦区金日世家北门东60米       1.322763
# 4               上海市浦东新区国展路1481号航融盛通大厦      78.971726
# ..                                ...            ...
# 195          上海市浦东新区福山路455号全华信息大厦一层大堂      18.390760
# 196          上海市虹口区同丰路与北宝兴路辅路交叉口东140米      22.715311
# 197  上海市长宁区天山路789号百盛优客城市广场东楼负一层E2001室      31.232050
# 198        上海市浦东新区世纪大道1217号百联世纪购物中心F5      46.008441
# 199         上海市普陀区中山北路2438号中瑞商务大厦一层大堂      20.667447
#
# [180 rows x 2 columns]>

# %%
ndata100
# Out:
#                                       adress     distance
# 2                   上海市黄浦区日月光618号9号线1号B2瑞幸咖啡   698.074124
# 15         上海市黄浦区马当路388号SOHO复兴广场E栋一层107号瑞幸咖啡   110.658331
# 16                         上海市嘉定区芳礼路161号瑞幸咖啡   247.178103
# 19         上海市虹口区东大名路1118号浦江国际金融大厦一层103室瑞幸咖啡   189.795822
# 22                  上海市黄浦区日月光618号9号线1号B2瑞幸咖啡   698.074124
# 35         上海市黄浦区马当路388号SOHO复兴广场E栋一层107号瑞幸咖啡   110.658331
# 36                         上海市嘉定区芳礼路161号瑞幸咖啡   247.178103
# 39         上海市虹口区东大名路1118号浦江国际金融大厦一层103室瑞幸咖啡   189.795822
# 40               上海市黄浦区南京东路299号宏伊国际广场B1层瑞幸咖啡   137.231636
# 45              上海市普陀区中江路388弄国盛中心1号101A室瑞幸咖啡   341.416832
# 47                上海市黄浦区南京西路388号仙乐斯广场负一层瑞幸咖啡   137.782031
# 48          上海市黄浦区蒙自路757号上海歌斐中心一层102A1单元瑞幸咖啡   759.246663
# 49                  上海市黄浦区淮海中路282香港广场F3层瑞幸咖啡   491.947719
# 50         上海市浦东新区峨山路91弄38-48号开伦鑫座大厦一层R区瑞幸咖啡   447.931216
# 54         上海市黄浦区中山南一路788号号博荟广场负二层B2-11室瑞幸咖啡   225.677010
# ...

# %%
coffeepoi = pd.read_csv("coffeepoi.csv")

# %%
coffeepoi = coffeepoi[~coffeepoi['adress'].duplicated(keep="first")]

# %%
poilist = coffeepoi["adress"].tolist()

# %%
len(poilist)
# Out:
# 175

# %%
coffeepoi.info
# Out:
# <bound method DataFrame.info of                                adress          lo         la
# 0     上海市静安区堡尼大厦西北门旁(延长路地铁站3号口步行140米)  121.454014  31.270729
# 1      上海市长宁区天山公园东门南250米(延安西路地铁站2号口旁)  121.416992  31.208817
# 2                上海市黄浦区日月光618号9号线1号B2  121.469360  31.201367
# 3                    上海市黄浦区金日世家北门东60米  121.495320  31.212605
# 4               上海市浦东新区国展路1481号航融盛通大厦  121.497639  31.185915
# ..                                ...         ...        ...
# 189          上海市浦东新区福山路455号全华信息大厦一层大堂  121.531929  31.224145
# 190          上海市虹口区同丰路与北宝兴路辅路交叉口东140米  121.467319  31.273050
# 191  上海市长宁区天山路789号百盛优客城市广场东楼负一层E2001室  121.403973  31.210638
# 192        上海市浦东新区世纪大道1217号百联世纪购物中心F5  121.526927  31.230068
# 193         上海市普陀区中山北路2438号中瑞商务大厦一层大堂  121.424630  31.244152
#
# [175 rows x 3 columns]>

# %%
coffeepoi.to_csv("output.csv",index=False,encoding="utf-8")
