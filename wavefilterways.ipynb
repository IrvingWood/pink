# %%
import matplotlib.pyplot as plt

# %%
moon=plt.imread("moonlanding.png")

# %%
plt.imshow(moon,cmap="gray")

# %%
from scipy import ndimage

# %%
plt.imshow(ndimage.gaussian_filter(moon,sigma=3),cmap="gray")

# %%
plt.imshow(ndimage.median_filter(moon,size=7),cmap="gray")

# %%
plt.imshow(moon,cmap="gray")

# %%
from scipy import signal

# %%
plt.imshow(signal.wiener(moon,))
