# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
# 设置图像的显示位置，设置图像在当前的文档中
# %matplotlib inline

# %% [markdown]
# Series和DataFrame都有一个用于生成各类图表的plot方法。默认情况下，他们所生成的是线形图

# %%
heros = pd.read_excel('王者英雄.xlsx')
heros.head()
# Out:
#      id name    血量  法术/\n怒气  物理\n攻击  法术\n攻击  物理\n防御  防御成\n长  法术\n防御  法防成\n长  \
# 0  1000  安琪拉  3323      490     170       0      83   0.121      50   0.076
# 1  1001  程咬金  3437        0     161       0     125   0.172      50   0.076
# 2  1002   妲己  3229      490     170       0      86   0.125      50   0.076
# 3  1003   项羽  3535      420     157       0     123   0.170      50   0.076
# 4  1004   亚瑟  3622        0     164       0      98   0.140      50   0.076
#
#     移速  5秒\n回血  5秒\n回蓝 攻击范围
# 0  360      47      17   远程
# 1  380      57       0   近战
# 2  340      46      18   远程
# 3  370      58      15   近战
# 4  390      55       0   近战

# %%
heros["id"].plot()
# Out:
# <Axes: >
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# ...

# %%
score = Series(data=np.random.randint(0,100,size=5), index=[1,2,3,4,5])
score
# Out:
# 1    19
# 2    69
# 3     3
# 4    69
# 5    19
# dtype: int64

# %%
score.plot()
# Out:
# <Axes: >
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# ...

# %%
score_df = DataFrame(data=np.random.randint(0,100,size=(10,3)),columns=["Python","Java","PHP"])
score_df
# Out:
#    Python  Java  PHP
# 0      47    73   98
# 1      64    79   63
# 2      77    16   25
# 3       0    17   77
# 4      69    70    8
# 5      91    82   56
# 6      72    11   99
# 7      26    84   88
# 8      43     9   91
# 9      18    68   64

# %%
# Index默认是x轴刻度
# 纵轴的刻度范围由我们表现的数据的范围决定
score_df.plot()
# Out:
# <Axes: >
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# ...

# %%
# 一般会结合时间来展示数据

# %%
price = Series(data=np.random.randint(100,200,size=5),index=list("ABCDE"))

# %%
price.plot(kind='bar')
# Out:
# <Axes: >
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# ...

# %%
# 各个开发商之间的比较
# 想通开发商不同楼盘的比较
price_df = DataFrame(data=np.random.randint(100,200,size=(5,3)),index=list("ABCDE"),columns=["wanda","hengda","wanke"])

# %%
price_df.plot(kind='bar')
# Out:
# <Axes: >
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# ...

# %%
price_df
# Out:
#    wanda  hengda  wanke
# A    126     128    142
# B    192     164    161
# C    137     149    143
# D    157     152    130
# E    108     165    164

# %%
price_df2=price_df.stack().unstack(level=-2)

# %%
price_df2.plot(kind='bar')
# Out:
# <Axes: >
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# ...

# %%
data = Series(data=np.random.randint(30,100,size=30))
# 设置图像的显示比例
plt.figure(figsize=(20,40))
data.plot(kind='barh')
# Out:
# <Axes: >
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# ...

# %%
heros
# Out:
#       id name    血量  法术/\n怒气  物理\n攻击  ...  法防成\n长   移速  5秒\n回血  5秒\n回蓝  攻击范围
# 0   1000  安琪拉  3323      490     170  ...   0.076  360      47      17    远程
# 1   1001  程咬金  3437        0     161  ...   0.076  380      57       0    近战
# 2   1002   妲己  3229      490     170  ...   0.076  340      46      18    远程
# 3   1003   项羽  3535      420     157  ...   0.076  370      58      15    近战
# 4   1004   亚瑟  3622        0     164  ...   0.076  390      55       0    近战
# ..   ...  ...   ...      ...     ...  ...     ...  ...     ...     ...   ...
# 56  1056   甄姬  3041      490     165  ...   0.076  340      43      18    远程
# 57  1057   钟馗  3420      490     162  ...   0.076  360      57      17    近战
# 58  1058  钟无艳  3150      430     164  ...   0.076  380      48      15    近战
# 59  1059   周瑜  3093      490     160  ...   0.076  350      44      17    远程
# 60  1060   庄周  3311      420     170  ...   0.076  390      55      15    近战
#
# [61 rows x 14 columns]

# %%
import matplotlib as mpl

# %%
#mpl.rc_params()

# %%
#mpl.rcParams['font.sans-serif']='SourceHanSansCN-Bold'

# %%
heros.groupby("攻击范围")["血量"].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='攻击范围'>
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# /home/kai/Desktop/demo/myenv/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 36817 (\N{CJK UNIFIED IDEOGRAPH-8FD1}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /home/kai/Desktop/demo/myenv/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 25112 (\N{CJK UNIFIED IDEOGRAPH-6218}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# /home/kai/Desktop/demo/myenv/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 36828 (\N{CJK UNIFIED IDEOGRAPH-8FDC}) missing from font(s) DejaVu Sans.
# ...

# %%
heros.head()
# Out:
#      id name    血量  法术/\n怒气  物理\n攻击  ...  法防成\n长   移速  5秒\n回血  5秒\n回蓝  攻击范围
# 0  1000  安琪拉  3323      490     170  ...   0.076  360      47      17    远程
# 1  1001  程咬金  3437        0     161  ...   0.076  380      57       0    近战
# 2  1002   妲己  3229      490     170  ...   0.076  340      46      18    远程
# 3  1003   项羽  3535      420     157  ...   0.076  370      58      15    近战
# 4  1004   亚瑟  3622        0     164  ...   0.076  390      55       0    近战
#
# [5 rows x 14 columns]

# %%
heros.groupby("攻击范围")[["血量","法术/\n怒气"]].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='攻击范围'>
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# /home/kai/Desktop/demo/myenv/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 36817 (\N{CJK UNIFIED IDEOGRAPH-8FD1}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /home/kai/Desktop/demo/myenv/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 25112 (\N{CJK UNIFIED IDEOGRAPH-6218}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# /home/kai/Desktop/demo/myenv/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 36828 (\N{CJK UNIFIED IDEOGRAPH-8FDC}) missing from font(s) DejaVu Sans.
# ...

# %%
#查看血量的分布状况
heros["血量"].plot(kind='hist',bins=5)
# Out:
# <Axes: ylabel='Frequency'>
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# ...

# %%
data = Series(data=np.random.randint(0,10,size=10))
data
# Out:
# 0    7
# 1    4
# 2    0
# 3    4
# 4    4
# 5    8
# 6    8
# 7    9
# 8    6
# 9    8
# dtype: int64

# %%
data.plot(kind='hist',bins=5)
# Out:
# <Axes: ylabel='Frequency'>
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# ...

# %%
data=Series(data=np.random.randn(1000))
data.plot(kind='hist',bins=200)
# Out:
# <Axes: ylabel='Frequency'>
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# ...

# %%
from scipy.stats import norm

# %%
data.plot(kind='hist',density=True)
data.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SourceHanSansCN-Bold
# ...

# %%
data1 = np.random.randn(1000)
data2 = np.random.randn(1000)
df = DataFrame(data={
    "A":data1,
    "B":data2,
    "C":np.random.randn(1000)
})

# %%
df.plot(kind="scatter",x="A",y="B")
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
# 查看两组数据之间的关系

# %%
heros.plot(kind="scatter", x="血量",y="法术/\n怒气")
# Out:
# <Axes: xlabel='血量', ylabel='法术/\n怒气'>
# /home/kai/Desktop/demo/myenv/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 34880 (\N{CJK UNIFIED IDEOGRAPH-8840}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /home/kai/Desktop/demo/myenv/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 37327 (\N{CJK UNIFIED IDEOGRAPH-91CF}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /home/kai/Desktop/demo/myenv/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 27861 (\N{CJK UNIFIED IDEOGRAPH-6CD5}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /home/kai/Desktop/demo/myenv/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 26415 (\N{CJK UNIFIED IDEOGRAPH-672F}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# ...

# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.plot(kind='scatter', x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
pd.plotting.scatter_matrix(df)
# Out:
# array([[<Axes: xlabel='A', ylabel='A'>, <Axes: xlabel='B', ylabel='A'>,
#         <Axes: xlabel='C', ylabel='A'>],
#        [<Axes: xlabel='A', ylabel='B'>, <Axes: xlabel='B', ylabel='B'>,
#         <Axes: xlabel='C', ylabel='B'>],
#        [<Axes: xlabel='A', ylabel='C'>, <Axes: xlabel='B', ylabel='C'>,
#         <Axes: xlabel='C', ylabel='C'>]], dtype=object)

# %%
tips["size"].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
# 如果希望表达离散值和连续值之间的关系，可以采用seaborn的高级图像表示

tips.plot(kind='scatter',x='tip',y='size')
# Out:
# <Axes: xlabel='tip', ylabel='size'>
