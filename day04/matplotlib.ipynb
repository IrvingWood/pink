# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 获取约会数据
# https://github.com/mwaskom/seaborn-data/tree/master 数据集链接
tips = sns.load_dataset('tips')

# %%
# pandas的绘图都是依赖于pandas对象
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
x=np.linspace(-1,1,100)
y=(1-x**2)**0.5

# %%
plt.plot(x,y)

# %%
plt.hist(tips["total_bill"],color="green",rwidth=0.8)
plt.show()

# %%
data=tips.groupby("day")["total_bill"].sum()
# Out:
# /tmp/ipykernel_1401363/2580137540.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data=tips.groupby("day")["total_bill"].sum()

# %%
plt.bar(x=np.arange(data.size),height=data)
plt.xticks([0,1,2,3],data.index)
# Out:
# ([<matplotlib.axis.XTick at 0x71ce93720590>,
# ...
#  [Text(0, 0, 'Thur'), Text(1, 0, 'Fri'), Text(2, 0, 'Sat'), Text(3, 0, 'Sun')])

# %%
data
# Out:
# day
# Thur    1096.33
# Fri      325.88
# Sat     1778.40
# Sun     1627.16
# Name: total_bill, dtype: float64

# %% [markdown]
# ## 获取画板对象

# %%
x=np.linspace(-np.pi,np.pi,100)

# %%
# 如果没有显示创建这个画板对象，cell中也会自动维护一个画板
figure=plt.figure(figsize=(5,2))
# 如果没有特殊的处理，一个cell中的所有图像，都默认显示在同一个画板中
plt.plot(x,np.sin(x))
# 设置此行代码之前的所有图像进行显示，如果没设置，会在cell末尾自动显示图像
plt.show()
plt.plot(x,np.cos(x))

# %%
# 单变量分析   Series

# 多变量分析   DataFrame

# %%
price=Series(data=np.random.randint(100,200,size=10),index=np.arange(10))
price.plot()
# Out:
# <Axes: >

# %%
price=DataFrame(data={
    "BGY":np.random.randint(100,200,size=10),
    "SMQH":np.random.randint(100,200,size=10),
    "LYHG":np.random.randint(100,200,size=10),
    
})
price.plot()
# Out:
# <Axes: >

# %%
# plot只画线形图
x=np.array([1,2])
y=np.array([4,3])
plt.plot(x,y)

# %%
x=np.linspace(1,10,10)

# %%
y=np.sin(x)

# %%
y
# Out:
# array([ 0.84147098,  0.90929743,  0.14112001, -0.7568025 , -0.95892427,
#        -0.2794155 ,  0.6569866 ,  0.98935825,  0.41211849, -0.54402111])

# %%
plt.plot(x,y)

# %%
# 绘制线形图，x必须是有序的，从小到大排序
x=np.sort(np.random.randint(0,10,size=10))
y=np.random.randint(0,10,size=10)

# %%
plt.plot(x,y)

# %%
x
# Out:
# array([2, 3, 4, 5, 5, 6, 7, 8, 9, 9])

# %%
y
# Out:
# array([3, 7, 8, 9, 1, 2, 4, 6, 5, 1])

# %%
x=np.linspace(0,2*np.pi,100)
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))

# %%
plt.plot(x,np.sin(x),x,np.cos(x),x,0.6*x)

# %% [markdown]
# ### <b>设置子画布</b>

# %%
# 画板——>画布——>呈现图像

# %%
# 画布和画板一样，如果不需要做一些额外设置，不需要显示调用它
# 常用操作是对画板进行分区，就要配置画布的位置
axes=plt.subplot()

# %%
# 调整画布的大小，可以通过调整画板来实现
plt.figure(figsize=(10,6))
axes1=plt.subplot(221)
# 在不同的画布中，绘制不同的图像
# 1，上下文原则：绘制函数会默认把图像绘制到离他最近的那个画布中
plt.plot(x,np.sin(x))
# 2,使用面向对象的方式绘制
axes1.plot(x,np.cos(x))

axes2=plt.subplot(222)

axes3=plt.subplot(223)

axes4=plt.subplot(224)
plt.plot(x,np.sin(x))

# %%
plt.grid()

# %%
plt.figure(figsize=(10,6))
axes1=plt.subplot(221)
plt.grid()
axes2=plt.subplot(222)
plt.grid(linewidth=3)
axes3=plt.subplot(223)
#plt.grid(color='#ffbbcc')
plt.grid(color=np.random.random(3))

axes4=plt.subplot(224)
axes4.grid(axis='x',alpha=0.1,color='#ff00ff')

# %%
# 颜色表示
# 1.HTML颜色名称 red blue green yellow yellowgreen purple darkgray lightgray gray，支持简称
# 2.十六进制字符串   "#00aaff"
# 3,RGB元组(0-1)float32 (0-255)uint8
# jpg代表的：三个0-255 uint8类型的整数
# png代表的：三个0-1 float32类型的小数

# %%
UI=plt.imread("UI.webp")

# %%
UI.shape
# Out:
# (889, 500, 3)

# %%
UI.dtype
# Out:
# dtype('uint8')

# %%
UI.max(),UI.min()
# Out:
# (np.uint8(255), np.uint8(0))

# %%
randomimage=np.random.randint(0,255,size=(100,100,3),dtype=np.uint8)
plt.imshow(randomimage)

# %%
randomimage2=np.random.random(size=(100,100,3))

# %%
randomimage2.dtype
# Out:
# dtype('float64')

# %%
plt.imshow(randomimage2)

# %%
np.random.random((8,3))
# Out:
# array([[0.81383547, 0.47148262, 0.22876396],
#        [0.72727786, 0.37817173, 0.47672267],
#        [0.52340859, 0.01526255, 0.9990309 ],
#        [0.53095116, 0.89287402, 0.50550853],
#        [0.73322715, 0.57661789, 0.81170424],
#        [0.97845343, 0.0061924 , 0.35558887],
#        [0.07778873, 0.78394065, 0.24688094],
#        [0.60370454, 0.73881594, 0.36743972]])

# %% [markdown]
# ### 坐标轴界限

# %%
# 坐标轴的界限默认由图像的内容确定
x =np.linspace(0,2*np.pi,100)

# %%
axes = plt.subplot(111)
plt.plot(x,np.sin(x))
plt.axis([-1,8,-2,2])
axes.axis([-2,10,-3,3])
# Out:
# (np.float64(-2.0), np.float64(10.0), np.float64(-3.0), np.float64(3.0))

# %%
plt.xlim()
plt.ylim()
axes.set_xlim()

# %%
# 单独对横轴和纵轴的边界处理
plt.plot(x,np.sin(x))
plt.xlim([-1,8])
plt.ylim([-2,2])
# Out:
# (-2.0, 2.0)

# %%
# 单独对横轴和纵轴的边界处理
axes=plt.subplot(111)
plt.plot(x,np.sin(x))
axes.set_xlim([-1,8])
axes.set_ylim([-2,2])
# Out:
# (-2.0, 2.0)

# %%
s =Student()
# 属性访问（面向对象的概念）
s.name="tom"  set函数
s.name        get函数

# %%
# plt.figure(figsize=(4,4))
x=np.linspace(-1,1,100)
y=(1-x**2)**0.5
plt.plot(x,y)
plt.plot(x,-y)
#调整横纵轴的比例 equal, scaled
# plt.axis('equal')
plt.axis('scaled')
#隐藏横轴和纵轴
plt.axis('off')
# 强制渲染前面的绘图代码
plt.show()

# %%
x=np.linspace(0,2*np.pi,100)
plt.plot(x,np.sin(x))
# 也可以加载自定义字体，见后续代码
plt.xlabel("data",color='red',rotation=90,fontdict={
    "fontsize":30
})
# 纵轴标签默认90°
plt.ylabel("value")
# Out:
# Text(0, 0.5, 'value')

# %%
x=np.linspace(0,2*np.pi,100)
axes=plt.subplot(111)
plt.plot(x,np.sin(x))
# 也可以加载自定义字体，见后续代码
axes.set_xlabel("data",color='red',rotation=90,fontdict={
    "fontsize":30
})
# 纵轴标签默认90°
axes.set_ylabel("value",fontsize=20)
# Out:
# Text(0, 0.5, 'value')

# %%
# 刻度值
# 刻度标签

# %%
x=np.linspace(0,2*np.pi,100)
plt.plot(x,np.sin(x))
# params1:要保留的刻度值（最好选择在数据的有效范围之内）
plt.xticks([0,np.pi/2,np.pi,3*np.pi/2,2*np.pi])
plt.show()

# %%
score = np.array([98,87,59,89,100])
plt.plot(np.arange(5),score)
#params2:刻度标签
plt.xticks([0,1,2,3,4],["luuna","jack","chery","irving","wood"])
plt.show()

# %%
score = np.array([98,87,59,89,100])
axes=plt.subplot(111)
plt.plot(np.arange(5),score)
#使用画布设定刻度位置
axes.set_xticks([0,1,2,3,4])
axes.set_xticklabels(["luunaluunaluunaluuna","jackjackjackjack","chery","irvingirvingirvingirving","wood"],fontdict={
    "color":'green',
    "fontsize":14,
    "rotation":30
})

plt.show()

# %%
x=np.linspace(0,2*np.pi,100)
plt.plot(x,np.sin(x))
# params1:要保留的刻度值（最好选择在数据的有效范围之内）
plt.xticks([0,np.pi/2,np.pi,3*np.pi/2,2*np.pi],["0","π/2","π","3π/2","2π"])
plt.yticks([-1,0,1],fontsize=18,color='red')
plt.show()

# %%
plt.figure(figsize=(10,4))
ax1=plt.subplot(1,2,1)
ax1.plot(x,np.sin(x))
plt.title("SIN",loc="left",color=np.random.random(3),fontsize=20)
ax2=plt.subplot(1,2,2)
ax2.plot(x,np.cos(x))
ax2.set_title("COS",rotation=30,color='red',fontsize=20)
plt.show()

# %% [markdown]
# ### 图例

# %%
# 图像的标注
# 【推荐】推荐的添加图例的方法
plt.plot(x,np.sin(x),label="SIN(X)")
plt.plot(x,np.cos(x),label="COS(X)")
# 开启图例，图例会显示每一个绘图（不止plot()）函数中的label参数的值显示出来
plt.legend()
plt.show()

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))

plt.legend(["SINX","COSX"])

# %%
# 图像的标注
# 【推荐】推荐的添加图例的方法
plt.plot(x,np.sin(x),label="SIN(X)")
plt.plot(x,np.cos(x),label="COS(X)")
# 开启图例，图例会显示每一个绘图（不止plot()）函数中的label参数的值显示出来
plt.legend(loc=0,ncol=2)
plt.show()

# %%
figure =plt.figure(figsize=(10,3),facecolor='orange')
x = np.linspace(0,2*np.pi,100)
plt.plot(x,np.sin(x),label="SIN(X)")
plt.legend()
figure.savefig('sin.png',dpi=100)

# %% [markdown]
# #### matplotlib常用的绘图元素的设置小姐
# 1. 画板对象
# figure = plt.figure(figsize)
#
# 3. 画布对象
# axes = plt.subplot(row,col,loc)
#
#
# 5. 网格线
# plt.grid()
#
#
# axes.grid()
# 7. 轴设置、刻度标签
# plt.axis([xmin,xmax, ymin,ymax])   设置界限
#
# plt.axis('equal')   设置横纵轴的比例
#
# plt.axis('off')    设置横纵轴的开启和关闭
#
# plt.xlim()  axes.set_xlim([])
#
# plt.ylim()  axes.set_ylim([])
# 9. 画布标题
# plt.title(s,color,fontsize,rotation,fontdict)
#
# axes.set_title(s,color,fontsize....)
#
# 10. 轴标题
# plt.xlabel()
#
# plt.ylabel()   axes.set_ylabel()
# 12. 刻度设置
# plt.xticks([刻度值列表],[刻度标签列表])
#
# plt.yticks([刻度值列表],[刻度标签列表])
#
# axes.set_xticks([刻度值列表])
#
# axes.set_xticklabels([刻度标签列表],color, fontsize....)
# 14. 图例
# 所有的绘图函数中，都有一个参数叫label,用于接收图例标签，配合legend()
#
# plt.plot(xxx,label="name")
#
# plt.legend(loc,ncol,color,fontsize...)

# %% [markdown]
# ## 设置plot的风格和样式

# %%
y = np.random.randint(10,20,size=6)
# 画布背景色
axes=plt.subplot(111,facecolor='yellow')
plt.plot(y,color='red',alpha=0.9,linestyle='None',marker='s')

# %%
x=np.linspace(0,2*np.pi,10)
style_dict={
    "-":"-",
    "--":"--",
    "-.":"-.",
    ":":":",
    # "steps":"steps",
    "None":"None"
}
def show_lines():
    padd=0
    for key,value in style_dict.items():
        padd+=1
        y = np.sin(x+padd)
        plt.plot(x,y,linestyle=value,label=key,color=np.random.random(3),linewidth=padd)
    plt.step(x,np.sin(x+padd+1),linewidth=padd+1)
    plt.legend()
show_lines()

# %%
dashes = [50,30,100,40,30,5]
plt.plot(y,dashes=dashes,color=np.random.random(3),label="salary",lw=3)
plt.legend()

# %% [markdown]
# ### 点型

# %%
# 图形中有点才能设置点形
# 1.线型图
# 2.散点图

# %%
point = np.random.randint(5,20,size=10)
color=np.random.random(3)

#marker 点型
#marker 点的大小
#markerfacecolor 点的主题颜色，必须有面积是封闭
#markeredgecolor 点的边线颜色
#markeredgewidth 点的边线宽度
plt.plot(point,ls='None',marker='o',markersize=20,markeredgecolor=color,markerfacecolor='None')
plt.plot(point,ls='None',marker='2',markersize=20,color=color)
plt.show()

# %%
plt.plot(point,marker='X',ls='None',markersize=20,markerfacecolor='green')

# %%
plt.plot(point,marker='|',ls='None',markersize=40,markeredgecolor='green',markeredgewidth=30)

# %%
plt.plot(x,y,ls,lw,marker,markersize,)

# %%
plt.plot(x1,y1,x2,y2,ls,lw,marker,markersize,)

# %%
plt.plot(x1,y1,'formatstring')

# %%
x=np.linspace(0,2*np.pi,20)
plt.plot(x,np.sin(x),'r--o',x,np.cos(x),'g-.s')
# 线和点的风格设置会影响到图例的显示
plt.legend(["sin(x)","cos(x)"])
plt.show()

# %%
# 绘图元素主要对画布
axes = plt.subplot(111)
axes.set_title("AXES-TITLE")
line1,line2=plt.plot(x,np.sin(x),x,np.cos(x))

line1.set_color(np.random.random(3))
line1.set_linewidth(3)
line1.set_markersize(15)
line1.set_marker('h')
line2.set_linestyle('--')
line2.set_color('blue')

# %%
type(line[0])
# Out:
# matplotlib.lines.Line2D
